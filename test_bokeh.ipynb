# %% [markdown]
# # bokehの実行
#
# studioで実施
# * Image: Base Python
# * Kernel: Python 3
# * Instance Type: ml.m5.large

# %% [markdown]
# Successfully built bokeh
# Installing collected packages: pyparsing, MarkupSafe, typing-extensions, pillow, packaging, numpy, Jinja2, bokeh
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 bokeh-2.3.3 numpy-1.19.5 packaging-21.3 pillow-8.4.0 pyparsing-3.0.9 typing-extensions-4.1.1

# %%
# !pip install bokeh

# %% [markdown]
# # 参考
# https://dev.classmethod.jp/articles/bokeh-tutorial/

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure 
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1101">Loading BokehJS ...</span>
#     </div>

# %%
x=[1, 2, 3, 4, 5]
y=[6, 7, 2, 4, 5]
# グラフ全体の設定を行う
p = figure(plot_width=400,        #描画するグラフの横幅
           plot_height=400,       #描画するグラフの縦幅 
           title="散布図"         #グラフのタイトル 
          )

p.circle(x=x,                   #X軸
         y=y,                   #Y軸
         size=15,               #グラフに対しての直径値 
         line_color="navy",     #円の線の色 
         fill_color="orange",   #円の色
         fill_alpha=0.5         #円の透明度
        )

show(p) # 設定した内容を表示させます。
# Out:
#   <div class="bk-root" id="47d78845-d3ba-4c71-98ce-1fda12ee9405" data-root-id="1102"></div>
